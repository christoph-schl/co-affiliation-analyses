# %% [markdown]
# # Impact plots

# %%
from maa.config.utils import configure_logging, LogLevel
from maa.config.constants import CONFIGURATION_PATH
from maa.plot.plot import create_plots_from_config

configure_logging(level=LogLevel.WARNING)
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Create impact plots from config
#
# It constructs the link and graph datasets for the **unfiltered (`CoAffAll`)** and **filtered (`CoAffStable`)** versions following the workflow in `create_co_affiliation_networks.ipynb`. It then computes the mwPR values (ToDo: add paper reference).

# %%
plots = create_plots_from_config(config_path=CONFIGURATION_PATH)
# Out:
# 2025-11-27T17:33:31.165468Z Dropped 249 affiliation link(s) from the DataFrame with no coordinates.
# 2025-11-27T17:33:33.597963Z dropped 22 nodes with missing hazen percentiles
# 2025-11-27T17:33:33.888165Z dropped 14 nodes with missing hazen percentiles
